# %% [markdown]
# <a href="https://colab.research.google.com/github/valorantJoln/LibreTV/blob/main/colab_webui.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Build environment 环境配置

# %%
# 查看当前使用GPU的CUDA版本
# !nvidia-smi
# Out:
# Sat May 16 08:02:25 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# # Git Clone 克隆代码

# %%
# %cd /content/

# 克隆项目代码到本地
# !git clone https://github.com/Kedreamix/Linly-Dubbing.git --depth 1

# 进入项目目录
# %cd Linly-Dubbing

# 初始化并更新子模块，如CosyVoice等
# !git submodule update --init --recursive
# Out:
# /content
# Cloning into 'Linly-Dubbing'...
# remote: Enumerating objects: 1034, done.
# remote: Counting objects: 100% (1034/1034), done.
# remote: Compressing objects: 100% (854/854), done.
# remote: Total 1034 (delta 125), reused 988 (delta 120), pack-reused 0 (from 0)
# Receiving objects: 100% (1034/1034), 41.22 MiB | 15.89 MiB/s, done.
# Resolving deltas: 100% (125/125), done.
# Updating files: 100% (910/910), done.
# /content/Linly-Dubbing
# Submodule 'CosyVoice' (https://github.com/FunAudioLLM/CosyVoice.git) registered for path 'CosyVoice'
# Cloning into '/content/Linly-Dubbing/CosyVoice'...
# Submodule path 'CosyVoice': checked out '6be8d0fc367f48c46a671edc16a99b9728038cb7'
# Submodule 'third_party/Matcha-TTS' (https://github.com/shivammehta25/Matcha-TTS.git) registered for path 'CosyVoice/third_party/Matcha-TTS'
# Cloning into '/content/Linly-Dubbing/CosyVoice/third_party/Matcha-TTS'...
# ...

# %%
# 查看torch版本
# !pip show torch
# Out:
# Name: torch
# Version: 2.10.0+cu128
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org
# Author:
# Author-email: PyTorch Team <packages@pytorch.org>
# License: BSD-3-Clause
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: cuda-bindings, filelock, fsspec, jinja2, networkx, nvidia-cublas-cu12, nvidia-cuda-cupti-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-runtime-cu12, nvidia-cudnn-cu12, nvidia-cufft-cu12, nvidia-cufile-cu12, nvidia-curand-cu12, nvidia-cusolver-cu12, nvidia-cusparse-cu12, nvidia-cusparselt-cu12, nvidia-nccl-cu12, nvidia-nvjitlink-cu12, nvidia-nvshmem-cu12, nvidia-nvtx-cu12, setuptools, sympy, triton, typing-extensions
# Required-by: accelerate, fastai, peft, sentence-transformers, timm, torchaudio, torchdata, torchvision

# %%
# 安装ffmpeg
# !apt-get install ffmpeg
# !ffmpeg -version
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 51 not upgraded.
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
# built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# 安装项目所需的Python包
# pynini is required by WeTextProcessing, use conda to install it as it can be executed on all platform.
# !conda install -y pynini==2.1.5 -c conda-forge
# -c https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge/

# !pip install pynini==2.1.5

# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 627.6/627.6 kB 14.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for pynini
#   Running setup.py clean for pynini
# Failed to build pynini
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (pynini)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.7/71.7 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 18.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 4.0 MB/s eta 0:00:00
# ...

# %%
# 安装submodules 下的依赖
# !pip install -r requirements_module.txt
# Out:
# Processing ./submodules/demucs
#   Preparing metadata (setup.py) ... done
# Processing ./submodules/whisper
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %% [markdown]
# # Download pretrained models 下载预训练模型

# %%
# 下载 wav2vec2 模型并保存到指定路径，如果文件已经存在，则跳过下载
# %mkdir -p models/ASR/whisper & wget -nc https://download.pytorch.org/torchaudio/models/wav2vec2_fairseq_base_ls960_asr_ls960.pth \
    -O models/ASR/whisper/wav2vec2_fairseq_base_ls960_asr_ls960.pth

# !python scripts/huggingface_download.py
# Out:
# --2026-05-16 08:03:31--  https://download.pytorch.org/torchaudio/models/wav2vec2_fairseq_base_ls960_asr_ls960.pth
# Resolving download.pytorch.org (download.pytorch.org)... 99.84.215.89, 99.84.215.85, 99.84.215.59, ...
# Connecting to download.pytorch.org (download.pytorch.org)|99.84.215.89|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 377664473 (360M) [application/x-www-form-urlencoded]
# Saving to: ‘models/ASR/whisper/wav2vec2_fairseq_base_ls960_asr_ls960.pth’
#
# models/ASR/whisper/ 100%[===================>] 360.17M   249MB/s    in 1.4s
#
# 2026-05-16 08:03:33 (249 MB/s) - ‘models/ASR/whisper/wav2vec2_fairseq_base_ls960_asr_ls960.pth’ saved [377664473/377664473]
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:189: UserWarning: The `resume_download` argument is deprecated and ignored in `snapshot_download`. Downloads always resume whenever possible.
#   warnings.warn(
# ...

# %% [markdown]
# # launch WebUI 启动WebUI

# %% [markdown]
# 首先将 `env.example`填入环境变量并 改名为 `.env`

# %%
# %cp env.example .env

# %%
# %cd /content/Linly-Dubbing/
# 测试one click是否正常
# !python -m tools.do_everything
# Out:
# /content/Linly-Dubbing
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/Linly-Dubbing/tools/do_everything.py", line 7, in <module>
#     from loguru import logger
# ModuleNotFoundError: No module named 'loguru'

# %%
# %cd /content/Linly-Dubbing/
# !pip install loguru moviepy demucs funasr modelscope accelerate HyperPyYAML librosa WeTextProcessing wget diffusers gdown pyarrow conformer lightning requests dotenv translators audiostretchy edge-tts openai gradio!pip install loguru moviepy demucs funasr modelscope accelerate HyperPyYAML librosa WeTextProcessing wget diffusers gdown pyarrow conformer lightning requests python-dotenv translators audiostretchy edge-tts openai gradio yt-dlp numpy transformers scipy%pip install loguru moviepy demucs%cd /content/Linly-Dubbing/
# !python webui.py
# Out:
# /content/Linly-Dubbing
# ERROR: Invalid requirement: 'gradio!pip': Expected end or semicolon (after name and no valid version specifier)
#     gradio!pip
#           ^
# Traceback (most recent call last):
#   File "/content/Linly-Dubbing/webui.py", line 3, in <module>
#     from tools.step010_demucs_vr import separate_all_audio_under_folder
#   File "/content/Linly-Dubbing/tools/step010_demucs_vr.py", line 2, in <module>
#     from demucs.api import Separator
# ModuleNotFoundError: No module named 'demucs.api'

# %% [markdown]
# ![](https://github.com/Kedreamix/Linly-Dubbing/blob/main/docs/webui.png)

# %%
# !pip install loguru moviepy demucs
# Out:
# ...
#   Using cached loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 28.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.1/87.1 kB 9.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# Using cached loguru-0.7.3-py3-none-any.whl (61 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.3/249.3 kB 22.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 8.8 MB/s eta 0:00:00
# ...
#   Created wheel for demucs: filename=demucs-4.0.1-py3-none-any.whl size=78388 sha256=d97211f1c0c3e23dcb28e5ef9a3de03c5a3752200566c21e99dbe508f5f548de
# ...

# %%
# !pip install loguru moviepy demucs gradio yt-dlp funasr modelscope
# Out:
# ...
#   Using cached yt_dlp-2026.3.17-py3-none-any.whl.metadata (182 kB)
# ...
#   Using cached funasr-1.3.1-py3-none-any.whl.metadata (37 kB)
# ...
#   Using cached modelscope-1.37.0-py3-none-any.whl.metadata (43 kB)
# ...
#   Using cached jamo-0.4.1-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached kaldiio-2.18.1-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached torch_complex-0.4.4-py3-none-any.whl.metadata (3.1 kB)
# ...
#   Using cached pytorch_wpe-0.0.1-py3-none-any.whl.metadata (242 bytes)
# ...
#   Using cached oss2-2.19.1-py3-none-any.whl
# ...
#   Using cached jaconv-0.5.0-py3-none-any.whl.metadata (8.9 kB)
# ...
#   Using cached hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached tensorboardx-2.6.5-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached crcmod-1.7-cp312-cp312-linux_x86_64.whl
# ...
#   Using cached pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# ...
#   Using cached aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl.metadata (1.5 kB)
# ...
